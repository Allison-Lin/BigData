# %% [markdown]
# <a href="https://colab.research.google.com/github/Allison-Lin/BigData/blob/master/%E9%85%8D%E8%89%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#安裝套件
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#載入套件
library(SportsAnalytics)
library(ggplot2)

# %%
#讀入資料
NBA1819 <- fetch_NBAPlayerStatistics("18-19")

# %%
#利用order()函數由大到小排序(decreasing = T)
NBA1819Order<-NBA1819[order(NBA1819$FieldGoalsMade,decreasing =T),]
NBA1819Order[1:20,"Name"] #逗號前方取1-20列；逗號後方放"Name"，表示取名稱為Name欄位
# Out:
#  [1] "James Harden"     "Bradley Beal"     "Kemba Walker"     "Gi Antetokounmpo"
#  [5] "Kevin Durant"     "Paul George"      "Nikola Vucevic"   "Lamarcu Aldridge"
#  [9] "Damian Lillard"   "Karl-antho Towns" "Donovan Mitchell" "D'angelo Russell"
# [13] "Klay Thompson"    "Stephen Curry"    "Demar Derozan"    "Russel Westbrook"
# [17] "Buddy Hield"      "Blake Griffin"    "Nikola Jokic"     "Tobias Harris"

# %%
#用subset()做欄位條件搜尋
subset(NBA1819,Position=="SG")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Alex Abrines     OKL  SG       31           588
# 7   NBA    De Akoon-purcell DEN  SG        7            23
# 9   NBA    Rawle Alkins     CHI  SG       10           120
# 10  NBA    Grayson Allen    UTA  SG       37           414
# 12  NBA    Kadeem Allen     NYK  SG       19           414
# 14  NBA    Justin Anderson  ATL  SG       46           460
# 26  NBA    Dwayne Bacon     CHA  SG       42           760
# 28  NBA    Ron Baker        WAS  SG       15           150
# 36  NBA    Nicolas Batum    CHA  SG       75          2357
# 39  NBA    Kent Bazemore    ATL  SG       67          1639
# 40  NBA    Bradley Beal     WAS  SG       82          3025
# 41  NBA    Malik Beasley    DEN  SG       81          1877
# 43  NBA    Marco Belinelli  SAN  SG       79          1818
# 53  NBA    Antonio Blakeney CHI  SG       56           829
# 56  NBA    Bogda Bogdanovic SAC  SG       70          1944
# ...

# %%
#用grepl()做字串條件搜尋
NBA1819[grepl("Booker",NBA1819$Name),]
# Out:
#    League Name         Team Position GamesPlayed TotalMinutesPlayed
# 61 NBA    Devin Booker PHO  SG       64          2241
#    FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 61 586            1255                135        414             ⋯ 56
#    Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 61 264       13     200           1                 1700        7
#    Ejections FlagrantFouls GamesStarted
# 61 0         0             64

# %%
install.packages("devtools")
devtools::install_github('cttobin/ggthemr')
library(ggthemr)
ggthemr("dust")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Skipping install of 'ggthemr' from a github remote, the SHA1 (3a86e281) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
#製作散佈圖 qplot(x軸名稱,y軸名稱,data=使用資料)
qplot(GamesPlayed,FieldGoalsMade,data=NBA1819)
# Out:
# plot without title

# %%
NBA1819$GamesPlayed <- as.factor(NBA1819$GamesPlayed)

# %%
#畫盒狀圖
ggplot(NBA1819,aes(GamesPlayed,FieldGoalsMade))+geom_boxplot()
# Out:
# plot without title

# %%
#畫長條圖
ggplot()+geom_bar(data=NBA1819,aes(x=GamesPlayed,y=FieldGoalsMade),stat="identity")
# Out:
# plot without title

# %%
#畫geom_line()
ggplot(NBA1819,aes(GamesPlayed,FieldGoalsMade))+geom_line()
# Out:
# plot without title
